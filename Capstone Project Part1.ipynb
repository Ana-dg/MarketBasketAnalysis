# %% [markdown]
#  # My Capstone Project

# %% [markdown]
#  ### 1. Business Problem

# %% [markdown]
# A client of a Real Estate agency requests to find the best zone for an apartment in Bucharest,Romania.<br>
# His main requests are:
# <ul>
#     <li>to be a family-friendly community</li>
#     <li>to be near the central zone</li>
#     <li>to have a park near the house</li>
#     <li>to be near the metro</li>
#     <li>to have at least one school in the neighbourhood</li>
# </ul>

# %% [markdown]
# ### Data Requirements

# %% [markdown]
# Sources
# <ul>
#     <li><b>The Foursquare location data</b>-<i> I will use the Foursquare location data to fill all the client's requested criteria</i></li>
#     <li><a href="https://www.regatta.ro/en/apartments-sale/">Link to the apartments in the selected zone</a>-<i> I will use the apartments website to see which are the offers in the zone</i></li>
